# %%
l=[3,5,6,77,55,33,21,23]

# %%
l[3]
# Out:
# 77

# %%
l[4]=37

# %%
l
# Out:
# [3, 5, 6, 77, 37, 33, 21, 23]

# %%
l.append(98) # append function adds the following in last

# %%
l
# Out:
# [3, 5, 6, 77, 37, 33, 21, 23, 98]

# %%
l2=[88,56,34]
l3=[43,28,97]

# %%
l.extend(l2) #it extends the following list

# %%
l
# Out:
# [3, 5, 6, 77, 37, 33, 21, 23, 98, 88, 56, 34]

# %%
l.extend(l3)

# %%
l
# Out:
# [3, 5, 6, 77, 37, 33, 21, 23, 98, 88, 56, 34, 43, 28, 97]

# %%
l.insert(3,33)

# %%
l
# Out:
# [3, 5, 6, 33, 77, 37, 33, 21, 23, 98, 88, 56, 34, 43, 28, 97]

# %%
number=l.pop(5)

# %%
number
# Out:
# 37

# %%
l.pop(5)
# Out:
# 33

# %%
l
# Out:
# [3, 5, 6, 33, 77, 21, 23, 98, 88, 56, 34, 43, 28, 97]

# %%
l.index(23)
# Out:
# 6

# %%
l.count(89)
# Out:
# 0

# %%
l.count(21)
# Out:
# 1

# %%
l.sort() #This function sorts and change the original one

# %%
l
# Out:
# [3, 5, 6, 21, 23, 28, 33, 34, 43, 56, 77, 88, 97, 98]

# %%
newl=[2,1,4,55,43,23,3,221,34]

# %%
sorted(newl) #This function new list in increasing order but doesnot change the original one
# Out:
# [1, 2, 3, 4, 23, 34, 43, 55, 221]

# %%
newl
# Out:
# [2, 1, 4, 55, 43, 23, 3, 221, 34]

# %%
y=[2,4,77,True, False,[4,5,7]] #list of lists

# %%
y
# Out:
# [2, 4, 77, True, False, [4, 5, 7]]

# %%
y[5]
# Out:
# [4, 5, 7]

# %%
y[5][2]
# Out:
# 7

# %%
list1=[22,12,34,56]
list2=[223,11,45,23]

# %%
list1+list2
# Out:
# [22, 12, 34, 56, 223, 11, 45, 23]

# %%
11 in list2
# Out:
# True

# %%
12 in list1
# Out:
# True

# %%
33 in list2
# Out:
# False

# %%
s="Jack-Abhay-Subham-AngelPriya-Bittu"

# %%
s
# Out:
# 'Jack-Abhay-Subham-AngelPriya-Bittu'

# %%
s.split("-")
# Out:
# ['Jack', 'Abhay', 'Subham', 'AngelPriya', 'Bittu']
