# %%
a= 30

# %%
if (a>50):             #(:)is known is inconjungtion
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
a=56                           # This is known as if-else ladder
if (a>70):
    print("Greater than 70")
elif (a>60):
    print("Greater than 60")
elif (a>50):
    print("Greater than 50")
else:
    print("Smaller")
# Out:
# Greater than 50

# %%
# if executes if the condition is true
#if-else adds and alternatuve block if the condition is false
#if-elif-else: Handles multiples conditions

# %%
def avg(a , b):
    return(a+b)/2

# %%
avg(3,7)
# Out:
# 5.0

# %%
def avg(a , b=15):
    return(a+b)/2

# %%
avg(9)
# Out:
# 12.0

# %%
def greet():
    print("Have a Nice Day!")

# %%
greet()
# Out:
# Have a Nice Day!
