# %%
Name= "Henry"
Age= 52

# %%
print("Hello, my name is {} and my age is {} years old". format(Name, Age))
# Out:
# Hello, my name is Henry and my age is 52 years old

# %%
print(f"Hello, my name is {Name} and my age is {Age} years old")
# Out:
# Hello, my name is Henry and my age is 52 years old

# %%
pi=3.14159
print(f"Round pi upto 2 decimal point: {pi:.2f}")
# Out:
# Round pi upto 2 decimal point: 3.14

# %%
print(f"{'Kangkan':>15}")   #Right Align
print(f"{'Kangkan':<15}")   #Left Align
print(f"{'Kangkan':^15}")   #Centre Align
# Out:
#         Kangkan
# Kangkan
#     Kangkan
