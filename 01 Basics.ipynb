# %%
a= 10

# %%
b= 15

# %%
a+b
# Out:
# 25

# %%
Name= "Kangkan"

# %%
type(a)
# Out:
# int

# %%
type(Name)
# Out:
# str

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
a=10
b=3.55
c="Huggies"
d=True

# %%
type(a), type(b), type(c), type(d)
# Out:
# (int, float, str, bool)

# %%
a="2344"

# %%
b="4577"

# %%
a+b
# Out:
# '23444577'

# %%
int(a) + int(b) #Typecasting
# Out:
# 6921
