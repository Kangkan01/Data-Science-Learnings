# %%
name="Kangkan"

# %%
type(name)
# Out:
# str

# %%
name
# Out:
# 'Kangkan'

# %%
name.count("a")
# Out:
# 2

# %%
name.upper()
# Out:
# 'KANGKAN'

# %%
name.lower()
# Out:
# 'kangkan'

# %%
name.endswith('an')
# Out:
# True

# %%
name.endswith('faaaa')
# Out:
# False

# %%
a='AndazApnaApna'

# %%
print(len(a))
# Out:
# 13

# %%
a[0:6]
# Out:
# 'AndazA'

# %%
a[1:-1]
# Out:
# 'ndazApnaApn'

# %%
a[-12:-1]
# Out:
# 'ndazApnaApn'

# %%
a[1:12]
# Out:
# 'ndazApnaApn'
