# %%
a=12
b=5

# %%
a+b
# Out:
# 17

# %%
a-b
# Out:
# 7

# %%
a*b
# Out:
# 60

# %%
a/b
# Out:
# 2.4

# %%
a//b  #Floor division
# Out:
# 2

# %%
a**b
# Out:
# 248832

# %%
a%b   # Remainder
# Out:
# 2

# %%
a=33
b=21

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=6
b=6

# %%
a == b
# Out:
# True

# %%
b1= True
b2= False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a= 10
b= 15

# %%
a&b
# Out:
# 10

# %%
a|b
# Out:
# 15

# %%
a= 56

# %%
a+=6

# %%
a
# Out:
# 62

# %%
a*=7

# %%
a
# Out:
# 434

# %%
a%=5

# %%
a
# Out:
# 4
