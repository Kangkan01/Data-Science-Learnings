# %%
code=400

# %%
match code:
    case 200: 
        print("Good Response")
    case 400:
        print("Bad Gateway")
    case 404:
        print("Server not found")
print("End of programming")
# Out:
# Bad Gateway
# End of programming

# %%
code=3000

# %%
match code:
    case 200: 
        print("Good Response")
    case 400:
        print("Bad Gateway")
    case 404:
        print("Server not found")
    case _:
        print("Unknown")
print("End of programming")
# Out:
# Unknown
# End of programming
