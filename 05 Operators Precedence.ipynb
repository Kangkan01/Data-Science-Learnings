# %%
# Pythons follow PEMDAS rule:
# P- Parenthesis, E- Exponential, M- Multiplication, D- Division/ Floor Division/ Modulas, A- Addition , S- Substraction
# Exponential is performed from right to left 
# Whereas Others all function is performed from left to right

# %%
a=2**2**5

# %%
a
# Out:
# 4294967296

# %%
54*3/3+7//9**2+(5*8)
# Out:
# 94.0
